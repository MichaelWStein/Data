# %%
import pandas as pd

# %%
import json
import pymongo

conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)   
db = client.analysis
db_dist_languages_wcalc = db.dist_languages_wcalc
db_prov_languages_wcalc = db.prov_languages_wcalc
db_seat_value_language = db.seat_value_language

# %%
dist_languages_wcalc = pd.read_pickle("dist_languages_wcalc.pkl")
dist_languages_wcalc
# Out:
#               rows                                     comment  \
# 0         district                         Electoral Districts
# 1         geo-code                 Link to Stascan information
# 2        Responses              Single Responses: Mothertongue
# 3          English                                        None
# 4           French                                        None
# 5     Non-official                                        None
# 6       Aboriginal                                        None
# 7     Afro-Asiatic               mainly Arabic, Hebrew, Somali
# 8   Austro-Asiatic                  includes Khmer, Vietnamese
# 9     Austronesian                includes Tagalog (Philipino)
# 10       Dravidian                              includes Tamil
# 11        European                 English and French excluded
# 12      Indo-Aryan                     includes Hindi, Urdu...
# 13         Iranian                    mainly Farsi and Kurdish
# 14      East Asian                  Japanese, Korean, Mongolic
# 15         African        Niger-Congo, Nilo-Saharan and Creole
# 16           Other          Sign languages and other languages
# 17         Chinese               mainly Mandarin and Cantonese
# 18   Tibeto-Burman                                        None
# 19       Tai-Kadai                         mainly Thai and Lao
# 20          Turkic                                        None
# 21           value  value of vote: above 1 better than average
#
#             Avalon  Bonavista--Burin--Trinity  \
# 0           Avalon  Bonavista--Burin--Trinity
# 1   2013A000410001             2013A000410002
# 2            85545                      73550
# 3            84870                      73005
# 4              195                        175
# 5              480                        370
# 6               15                         10
# 7               30                         70
# 8                5                          5
# 9               35                         35
# 10              10                         15
# 11             220                        130
# 12              40                         20
# 13               5                          5
# 14              10                          0
# 15               5                         30
# 16              15                         20
# 17              75                         35
# 18               0                          0
# 19               5                          0
# 20               0                          5
# 21         1.17412                     1.3656
#
#     Coast of Bays--Central--Notre Dame        Labrador  Long Range Mountains  \
# 0   Coast of Bays--Central--Notre Dame        Labrador  Long Range Mountains
# 1                       2013A000410003  2013A000410004        2013A000410005
# 2                                76955           26825                 85670
# 3                                76320           23190                 84485
# 4                                  150             410                   565
# 5                                  485            3225                   620
# 6                                   15            2535                    15
# 7                                   65              20                    80
# 8                                    0               0                     0
# 9                                   65             360                    80
# 10                                  20              15                    25
# 11                                 120             145                   225
# 12                                  55             105                    85
# 13                                  10               0                     5
# 14                                   5              10                     5
# 15                                  25              10                     5
# 16                                  15               5                    15
# 17                                  85              20                    75
# 18                                   0               0                     0
# 19                                  10               0                     5
# 20                                   0               0                     0
# 21                             1.30518         3.74427               1.17241
#
#     St. John's East  St. John's South--Mount Pearl        Cardigan  \
# 0   St. John's East  St. John's South--Mount Pearl        Cardigan
# 1    2013A000410006                 2013A000410007  2013A000411001
# 2             84125                          81315           36200
# 3             78920                          78915           33850
# 4               525                            330             505
# 5              4675                           2070            1850
# 6                20                             15              25
# 7               690                            345              85
# 8                30                             15              10
# 9               330                            200              45
# 10              155                             30              10
# 11             1075                            565             495
# 12              800                            230              95
# 13              190                             55              45
# 14              120                             35              65
# 15              210                            100              20
# 16               35                             40               5
# 17              925                            380             950
# 18                5                             20               5
# 19               20                              5               5
# 20               45                             20              10
# 21          1.19394                         1.2352         2.77459
#
#          ...        Vancouver Granville  North Island--Powell River  \
# 0        ...        Vancouver Granville  North Island--Powell River
# 1        ...             2013A000459036              2013A000459037
# 2        ...                      99130                      104005
# 3        ...                      56190                       94945
# 4        ...                       1600                        2160
# 5        ...                      41335                        6900
# 6        ...                         10                         540
# 7        ...                        820                          85
# 8        ...                        405                         185
# 9        ...                       2380                         430
# 10       ...                        160                          20
# 11       ...                       7235                        4510
# 12       ...                       1365                         220
# 13       ...                        875                          40
# 14       ...                       2635                         335
# 15       ...                         70                          30
# 16       ...                         25                          35
# 17       ...                      25085                         405
# 18       ...                         25                           5
# 19       ...                        125                          65
# 20       ...                        110                           0
# 21       ...                    1.01321                    0.965723
#
#     Vancouver Kingsway  Vancouver Quadra  Vancouver South        Victoria  \
# 0   Vancouver Kingsway  Vancouver Quadra  Vancouver South        Victoria
# 1       2013A000459038    2013A000459039   2013A000459040  2013A000459041
# 2                99760            102680            96860          112055
# 3                40560             62200            32075           93960
# 4                  905              1640              570            2000
# 5                58290             38835            64215           16095
# 6                   20                60               25              45
# 7                  440               770              525             830
# 8                 4740               135             2545             290
# 9                 8800               760             8110            1420
# 10                 525               145              955             125
# 11                6645              8545             5425            6425
# 12                3970              1010            11965             885
# 13                 315              1110              540             440
# 14                1890              3130             1580            1310
# 15                 110                60              150             130
# 16                  65                25               35              35
# 17               30215             22705            32015            3920
# 18                 275                25              135              20
# 19                 195               120              110             125
# 20                  95               220               80              90
# 21             1.00682          0.978185          1.03696        0.896346
#
#    West Vancouver--Sunshine Coast--Sea to Sky Country           Yukon  \
# 0   West Vancouver--Sunshine Coast--Sea to Sky Cou...           Yukon
# 1                                      2013A000459042  2013A000460001
# 2                                              116420           34885
# 3                                               89170           29110
# 4                                                2370            1565
# 5                                               24885            4210
# 6                                                 220             675
# 7                                                 305              55
# 8                                                 105              50
# 9                                                1325             995
# 10                                                 50              55
# 11                                               7945            1565
# 12                                               1595             195
# 13                                               4530              25
# 14                                               1705             135
# 15                                                 45              55
# 16                                                 25              15
# 17                                               6775             345
# 18                                                 15               0
# 19                                                 70              30
# 20                                                170               0
# 21                                           0.862738         2.87917
#
#     Northwest Territories         Nunavut
# 0   Northwest Territories         Nunavut
# 1          2013A000461001  2013A000462001
# 2                   40565           34955
# 3                   31765           11020
# 4                    1175             595
# 5                    7625           23340
# 6                    4640           22615
# 7                     215              75
# 8                     165               5
# 9                     910             175
# 10                     65              20
# 11                    795             195
# 12                    245              80
# 13                     35              10
# 14                    105              15
# 15                    185              80
# 16                      5              25
# 17                    250              45
# 18                      5               0
# 19                      5               5
# 20                     10               5
# 21                2.47603         2.87341
#
# [22 rows x 340 columns]

# %%
#records = json.loads(dist_languages_wcalc.set_index('rows').to_json(orient='records'))
#db_dist_languages_wcalc.insert(records,check_keys=False)

# error: InvalidDocument: key 'St. John's East' must not contain '.'

records = json.loads(dist_languages_wcalc.set_index('rows').to_json()).values()
db_dist_languages_wcalc.insert_many(records)

# %%
prov_languages_wcalc = pd.read_pickle("prov_languages_wcalc.pkl")
prov_languages_wcalc
# Out:
#               rows                               comment          Canada  \
# 0         district                   Electoral Districts          Canada
# 1         geo-code           Link to Stascan information  2016A000011124
# 2        Responses        Single Responses: Mothertongue     3.39486e+07
# 3          English                                  None     1.94608e+07
# 4           French                                  None     7.16670e+06
# 5     Non-official                                  None     7.32106e+06
# 6       Aboriginal                                  None          195700
# 7     Afro-Asiatic         mainly Arabic, Hebrew, Somali          575365
# 8   Austro-Asiatic            includes Khmer, Vietnamese          177520
# 9     Austronesian          includes Tagalog (Philipino)          511480
# 10       Dravidian                        includes Tamil          189405
# 11        European           English and French excluded     2.64827e+06
# 12      Indo-Aryan               includes Hindi, Urdu...     1.06476e+06
# 13         Iranian              mainly Farsi and Kurdish          242805
# 14      East Asian            Japanese, Korean, Mongolic          198640
# 15         African  Niger-Congo, Nilo-Saharan and Creole          169370
# 16           Other    Sign languages and other languages           11190
# 17         Chinese         mainly Mandarin and Cantonese     1.25336e+06
# 18   Tibeto-Burman                                  None           15850
# 19       Tai-Kadai                   mainly Thai and Lao           22010
# 20          Turkic                                  None           40140
# 21           seats                                  None             338
# 22           votes                        votes per seat          100440
# 23      percentage                         value of vote               1
#
#     Newfoundland and Labrador  Prince Edward Island  Nova Scotia  \
# 0   Newfoundland and Labrador  Prince Edward Island  Nova Scotia
# 1                 2016A000210           2016A000211  2016A000212
# 2                      513980                140020       904240
# 3                      499710                128005       830220
# 4                        2350                  4865        29465
# 5                       11920                  7155        44550
# 6                        2620                    50         4290
# 7                        1295                   655         7760
# 8                          60                   115          505
# 9                        1120                   395         2235
# 10                        275                   110         1010
# 11                       2470                  1980        14175
# 12                       1325                   500         3385
# 13                        280                   180         1425
# 14                        170                   215         1460
# 15                        390                   100          800
# 16                        145                    25          215
# 17                       1590                  2740         6635
# 18                         30                    45           30
# 19                         50                    20          155
# 20                         70                    20          445
# 21                          7                     4           11
# 22                    73425.7                 35005      82203.6
# 23                    1.36791                2.8693      1.22184
#
#     New Brunswick       Quebec      Ontario     Manitoba  Saskatchewan  \
# 0   New Brunswick       Quebec      Ontario     Manitoba  Saskatchewan
# 1     2016A000213  2016A000224  2016A000235  2016A000246   2016A000247
# 2          726990  7.88165e+06   1.2947e+07  1.23012e+06   1.06468e+06
# 3          472725       601155  8.90232e+06       900610        892615
# 4          231110  6.21966e+06       490715        40520         15100
# 5           23150  1.06083e+06  3.55392e+06       288985        156960
# 6            2165        45570        22765        29710         28340
# 7            3190       197535       253830        10700          6770
# 8             640        36330        78650         4185          2560
# 9            1375        21635       194380        52905         23415
# 10            285        14865       148605         1565          1560
# 11           7725       483570   1.3684e+06       127490         52390
# 12           1175        45845       565600        29520         19995
# 13            655        29760       139675         2705          2065
# 14           1665         7875        83440         4320          2030
# 15            840        85690        48625         4860          2865
# 16            170         2015         4505          595           300
# 17           3085        76490       602610        18305         12460
# 18             30          345         9185          575          1040
# 19             60         4895         8485         1120           525
# 20            105         7980        22615          340           360
# 21             10           78          121           14            14
# 22          72699       101047       107000      87865.4       76048.2
# 23        1.38158     0.993992     0.938692      1.14311       1.32074
#
#         Alberta  British Columbia        Yukon  Northwest Territories  \
# 0       Alberta  British Columbia        Yukon  Northwest Territories
# 1   2016A000248       2016A000259  2016A000260            2016A000261
# 2   3.93458e+06         4.495e+06        34885                  40565
# 3   2.99148e+06       3.17011e+06        29105                  31765
# 4         72150             57425         1570                   1175
# 5        870940       1.26746e+06         4210                   7625
# 6         23835              8435          675                   4635
# 7         68415             24870           50                    215
# 8         25400             28880           50                    165
# 9        115405             96535          990                    910
# 10        13490              7500           55                     60
# 11       283575            303935         1565                    795
# 12       145900            251000          190                    245
# 13        19600             46390           25                     35
# 14        23340             73870          140                    100
# 15        19975              4905           50                    180
# 16         1520              1655           25                     10
# 17       120375            408415          350                    250
# 18         2075              2500            0                      0
# 19         2670              3985           30                     10
# 20         4050              4140            0                      5
# 21           34                42            1                      1
# 22       115723            107024        34885                  40565
# 23     0.867933          0.938481      2.87917                2.47602
#
#         Nunavut
# 0       Nunavut
# 1   2016A000262
# 2         34960
# 3         11020
# 4           595
# 5         23345
# 6         22610
# 7            75
# 8             5
# 9           175
# 10           20
# 11          195
# 12           80
# 13           10
# 14           10
# 15           75
# 16           25
# 17           50
# 18            5
# 19            0
# 20            5
# 21            1
# 22        34960
# 23      2.87299

# %%
records = json.loads(prov_languages_wcalc.set_index('rows').to_json()).values()
db_prov_languages_wcalc.insert_many(records)

# %%
seat_value_language = pd.read_pickle("seat_value_language.pkl")
seat_value_language
# Out:
#               rows                               comment          Canada  \
# 0         district                   Electoral Districts          Canada
# 1         geo-code           Link to Stascan information  2016A000011124
# 2        Responses        Single Responses: Mothertongue     3.39486e+07
# 3          English                                  None     1.94608e+07
# 4           French                                  None     7.16670e+06
# 5     Non-official                                  None     7.32106e+06
# 6       Aboriginal                                  None          195700
# 7     Afro-Asiatic         mainly Arabic, Hebrew, Somali          575365
# 8   Austro-Asiatic            includes Khmer, Vietnamese          177520
# 9     Austronesian          includes Tagalog (Philipino)          511480
# 10       Dravidian                        includes Tamil          189405
# 11        European           English and French excluded     2.64827e+06
# 12      Indo-Aryan               includes Hindi, Urdu...     1.06476e+06
# 13         Iranian              mainly Farsi and Kurdish          242805
# 14      East Asian            Japanese, Korean, Mongolic          198640
# 15         African  Niger-Congo, Nilo-Saharan and Creole          169370
# 16           Other    Sign languages and other languages           11190
# 17         Chinese         mainly Mandarin and Cantonese     1.25336e+06
# 18   Tibeto-Burman                                  None           15850
# 19       Tai-Kadai                   mainly Thai and Lao           22010
# 20          Turkic                                  None           40140
# 21           seats                                  None             338
# 22           votes                        votes per seat          100440
# 23      percentage                         value of vote               1
#
#              id_seats                       act_seats  \
# 0   seats, ideal case  seats, calculating by district
# 1                 N/A                             N/A
# 2             337.999                             338
# 3             193.756                         195.374
# 4             71.3531                         72.0533
# 5             72.8899                         70.5713
# 6             1.94843                         2.84216
# 7             5.72844                         5.47697
# 8             1.76742                         1.68124
# 9             5.09239                         4.99402
# 10            1.88575                         1.80065
# 11            26.3667                         25.2534
# 12             10.601                         9.87392
# 13            2.41741                         2.26953
# 14             1.9777                          1.8569
# 15            1.68628                         1.64046
# 16            0.11141                        0.109096
# 17            12.4787                         11.9835
# 18           0.157806                          0.1529
# 19           0.219136                        0.212157
# 20           0.399642                        0.378437
# 21                N/A                             N/A
# 22                N/A                             N/A
# 23                N/A                             N/A
#
#                         value
# 0   value - > 1 is overvalued
# 1                         N/A
# 2                           1
# 3                     1.00835
# 4                     1.00981
# 5                     0.96819
# 6                     1.45869
# 7                    0.956101
# 8                    0.951236
# 9                    0.980681
# 10                   0.954871
# 11                   0.957777
# 12                   0.931417
# 13                   0.938826
# 14                   0.938918
# 15                   0.972827
# 16                   0.979232
# 17                   0.960314
# 18                   0.968916
# 19                   0.968153
# 20                    0.94694
# 21                        N/A
# 22                        N/A
# 23                        N/A

# %%
records = json.loads(seat_value_language.set_index('rows').to_json()).values()
db_seat_value_language.insert_many(records)
