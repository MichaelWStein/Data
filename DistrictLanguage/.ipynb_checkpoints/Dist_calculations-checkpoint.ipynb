# %%
import pandas as pd

dist_lan_df = pd.read_pickle("dist_languages.pkl")


#prov_list = prov_lan_df.loc[0]

#print(prov_list[0])

#seats = ["seats", None, 338, 7, 4, 11, 10, 78, 121, 14, 14, 34, 42, 1, 1, 1]

dist_lan_df
# Out:
#               rows                               comment          Avalon  \
# 0         district                   Electoral Districts          Avalon
# 1         geo-code           Link to Stascan information  2013A000410001
# 2        Responses        Single Responses: Mothertongue           85545
# 3          English                                  None           84870
# 4           French                                  None             195
# 5     Non-official                                  None             480
# 6       Aboriginal                                  None              15
# 7     Afro-Asiatic         mainly Arabic, Hebrew, Somali              30
# 8   Austro-Asiatic            includes Khmer, Vietnamese               5
# 9     Austronesian          includes Tagalog (Philipino)              35
# 10       Dravidian                        includes Tamil              10
# 11        European           English and French excluded             220
# ...

# %%
#lan_df = prov_lan_df.append(pd.Series(seats, index=prov_lan_df.columns ), ignore_index=True)

#lan_df

# %%
calc = []
ref_str = ['value', 'value of vote: above 1 better than average']
y=0

#Averge of votes required for one representative (Canada wide)
average = 100440

for column in dist_lan_df:
    # print(column)
    # print( type(lan_df.loc[2, column]))
    if isinstance(dist_lan_df.loc[2, column], float):
        ref = average/dist_lan_df.loc[2, column]
    else:
        ref = ref_str[y]
        y=y+1
        
    calc.append(ref)
    # print(calc)
    #== 'class float'):
    #    print("float")
    #= 'float':
    #        ref = lan_df.loc[2, column]/lan_df.loc[21, column]
    #print(ref)

#type([ref])
lan_df = dist_lan_df.append(pd.Series(calc, index=dist_lan_df.columns ), ignore_index=True)

#need to look at complete df for overview
pd.set_option('display.max_columns', 1000)

lan_df
# Out:
#               rows                                     comment  \
# 0         district                         Electoral Districts
# 1         geo-code                 Link to Stascan information
# 2        Responses              Single Responses: Mothertongue
# 3          English                                        None
# 4           French                                        None
# 5     Non-official                                        None
# 6       Aboriginal                                        None
# 7     Afro-Asiatic               mainly Arabic, Hebrew, Somali
# 8   Austro-Asiatic                  includes Khmer, Vietnamese
# 9     Austronesian                includes Tagalog (Philipino)
# 10       Dravidian                              includes Tamil
# 11        European                 English and French excluded
# 12      Indo-Aryan                     includes Hindi, Urdu...
# 13         Iranian                    mainly Farsi and Kurdish
# ...

# %%
lan_df.to_pickle("dist_languages_wcalc.pkl")

print("Df saved")

# Need to put a new df together with percentage informations for languages.
# First retrieve provincial df for basic set-up and calculations.

prov_calc_df = pd.read_pickle("prov_languages_wcalc.pkl")

prov_calc_df
# Out:
# Df saved
#               rows                               comment          Canada  \
# 0         district                   Electoral Districts          Canada
# 1         geo-code           Link to Stascan information  2016A000011124
# 2        Responses        Single Responses: Mothertongue     3.39486e+07
# 3          English                                  None     1.94608e+07
# 4           French                                  None     7.16670e+06
# 5     Non-official                                  None     7.32106e+06
# 6       Aboriginal                                  None          195700
# 7     Afro-Asiatic         mainly Arabic, Hebrew, Somali          575365
# 8   Austro-Asiatic            includes Khmer, Vietnamese          177520
# 9     Austronesian          includes Tagalog (Philipino)          511480
# 10       Dravidian                        includes Tamil          189405
# 11        European           English and French excluded     2.64827e+06
# ...

# %%
lan_calc_df = prov_calc_df[['rows', 'comment', 'Canada']]

print(prov_calc_df.loc[20, 'Canada'])

id_seats = ['seats, ideal case', 'N/A']
i = 2

for i in range (2, 21):
    res = prov_calc_df.loc[i, 'Canada']/average
    id_seats.append(res)


for i in range (0, 3):
    id_seats.append('N/A')
    
len(id_seats)

#len(lan_calc_df[['rows']])

lan_calc_df['id_seats'] = id_seats

#for column in lan_calc_df:
#    # print(column)
    # print( type(lan_df.loc[2, column]))
#    if isinstance(lan_calc_df.loc[2, column], float):
#        ref = average/lan_calc_df.loc[2, column]
#    else:
#        ref = ref_str[y]
#        y=y+1
        
#    calc.append(ref)
    # print(calc)
    #== 'class float'):
    #    print("float")
    #= 'float':
    #        ref = lan_df.loc[2, column]/lan_df.loc[21, column]
    #print(ref)

#type([ref])
#lan_df = dist_lan_df.append(pd.Series(calc, index=dist_lan_df.columns ), ignore_index=True)




lan_calc_df
# Out:
# 40140.0
# C:\Users\esouser\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#               rows                               comment          Canada  \
# 0         district                   Electoral Districts          Canada
# 1         geo-code           Link to Stascan information  2016A000011124
# 2        Responses        Single Responses: Mothertongue     3.39486e+07
# 3          English                                  None     1.94608e+07
# 4           French                                  None     7.16670e+06
# 5     Non-official                                  None     7.32106e+06
# 6       Aboriginal                                  None          195700
# ...

# %%
# Running the calculations on the district dataframe

calc = ['seats, calculating by district', 'N/A']


#Averge of votes required for one representative (Canada wide)
average = 100440

for i in range (2, 21):
    res = 0
    for column in lan_df:
        if isinstance(lan_df.loc[2, column], float):
            res = res + lan_df.loc[i, column]/lan_df.loc[2, column]
        
    calc.append(res)

for i in range (0, 3):
    calc.append('N/A')

lan_calc_df['act_seats'] = calc
        


calc2 = ['value - > 1 is overvalued', 'N/A']


for i in range (2, 21):
    res = lan_calc_df.loc[i, 'act_seats']/lan_calc_df.loc[i, 'id_seats']   
    calc2.append(res)

for i in range (0, 3):
    calc2.append('N/A')

lan_calc_df['value'] = calc2
        
   
    
lan_calc_df

lan_calc_df.to_pickle("seat_value_language.pkl")
# Out:
# C:\Users\esouser\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\esouser\Anaconda3\lib\site-packages\ipykernel_launcher.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
